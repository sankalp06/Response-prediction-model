# %%
import pickle
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler

with open('./Marketing_campaign.pkl', 'rb') as f:
    loaded_svc_rbl = pickle.load(f)


import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
# Creating tkinter window
window = tk.Tk()

width= window.winfo_screenwidth() 
height= window.winfo_screenheight()
#setting tkinter window size
window.geometry("%dx%d" % (width, height))
window.title('Marketing_campaign')



#Column 1 
age = ttk.Label(window, text = "age :", font = ("Times New Roman", 10)).grid(column = 0,  row = 0, padx = 10, pady = 25)
age_var=tk.StringVar()
age_entrybox=ttk.Entry(window,width=27,textvariable=age_var)
age_entrybox.grid(row=0,column=1)

#Column 2
job = ttk.Label(window, text = "Select the Job :", font = ("Times New Roman", 10)).grid(column = 0,  row = 1, padx = 10, pady = 25)
job_var = tk.StringVar()
job_choosen = ttk.Combobox(window, width = 27, textvariable = job_var)
job_choosen['values'] = ('blue-collar', 'technician', 'management', 'services','retired', 'admin.', 'housemaid', 'unemployed', 'entrepreneur', 'self-employed', 'unknown', 'student')
job_choosen.grid(column = 1, row = 1)
job_choosen.current(1) 


#Column 3
marital = ttk.Label(window, text = "Select the marital :", font = ("Times New Roman", 10)).grid(column = 0,  row = 2, padx = 10, pady = 25)
marital_var = tk.StringVar()
marital_choosen = ttk.Combobox(window, width = 27, textvariable = marital_var)
marital_choosen['values'] = ('married', 'single', 'divorced', 'unknown')
marital_choosen.grid(column = 1, row = 2)
marital_choosen.current(1)



#Column 4
education = ttk.Label(window, text = "Select the education :", font = ("Times New Roman", 10)).grid(column = 0,  row = 3, padx = 10, pady = 25)
education_var = tk.StringVar()
education_choosen = ttk.Combobox(window, width = 27, textvariable = education_var)
education_choosen['values'] = ('basic.4y', 'unknown', 'university.degree', 'high.school', 'basic.9y','professional.course', 'basic.6y', 'illiterate')
education_choosen.grid(column = 1, row = 3)
education_choosen.current(1)


#Column 5
default = ttk.Label(window, text = "Select the default :", font = ("Times New Roman", 10)).grid(column = 0,  row = 4, padx = 10, pady = 25)
default_var = tk.StringVar()
default_choosen = ttk.Combobox(window, width = 27, textvariable = default_var)
default_choosen['values'] = ('unknown', 'no', 'yes')
default_choosen.grid(column = 1, row = 4)
default_choosen.current(1)


#Column 6
housing = ttk.Label(window, text = "Select the housing :", font = ("Times New Roman", 10)).grid(column = 0,  row = 5, padx = 10, pady = 25)
housing_var = tk.StringVar()
housing_choosen = ttk.Combobox(window, width = 27, textvariable = housing_var)
housing_choosen['values'] = ('unknown', 'no', 'yes')
housing_choosen.grid(column = 1, row = 5)
housing_choosen.current(1)


#Column 7
loan = ttk.Label(window, text = "Select the loan_satus :", font = ("Times New Roman", 10)).grid(column = 0,  row = 6, padx = 10, pady = 25)
loan_var = tk.StringVar()
loan_choosen = ttk.Combobox(window, width = 27, textvariable = loan_var)
loan_choosen['values'] = ('unknown', 'no', 'yes')
loan_choosen.grid(column = 1, row = 6)
loan_choosen.current(1)

#Column 8
contact = ttk.Label(window, text = "Select the contact :", font = ("Times New Roman", 10)).grid(column = 0,  row = 7, padx = 10, pady = 25)
contact_var = tk.StringVar()
contact_choosen = ttk.Combobox(window, width = 27, textvariable = contact_var)
contact_choosen['values'] = ('cellular', 'telephone')
contact_choosen.grid(column = 1, row = 7)
contact_choosen.current(1)

#Column 9
month = ttk.Label(window, text = "Select the month :", font = ("Times New Roman", 10)).grid(column = 0,  row = 8, padx = 10, pady = 25)
month_var = tk.StringVar()
month_choosen = ttk.Combobox(window, width = 27, textvariable = month_var)
month_choosen['values'] = ('aug', 'nov', 'jun', 'apr', 'jul', 'may', 'oct', 'mar', 'sep', 'dec','feb','jan')
month_choosen.grid(column = 1, row = 8)
month_choosen.current(1)

#Column 10
day_of_week = ttk.Label(window, text = "Select the day :", font = ("Times New Roman", 10)).grid(column = 0,  row = 9, padx = 10, pady = 25)
day_of_week_var = tk.StringVar()
day_of_week_choosen = ttk.Combobox(window, width = 27, textvariable = day_of_week_var)
day_of_week_choosen['values'] = ('thu', 'fri','sat', 'sun', 'tue', 'mon', 'wed')
day_of_week_choosen.grid(column = 1, row = 9)
day_of_week_choosen.current(1)


#Column 11
poutcome = ttk.Label(window, text = "Select the poutcome :", font = ("Times New Roman", 10)).grid(column = 10,  row = 0, padx = 10, pady = 25)
poutcome_var = tk.StringVar()
poutcome_choosen = ttk.Combobox(window, width = 27, textvariable = poutcome_var)
poutcome_choosen['values'] = ('nonexistent', 'success', 'failure')
poutcome_choosen.grid(column = 11, row = 0)
poutcome_choosen.current(1)


#Column 12
emp_var_rate = ttk.Label(window, text = "emp_var_rate :", font = ("Times New Roman", 10)).grid(column = 10,  row = 1, padx = 10, pady = 25)
emp_var_rate_var=tk.StringVar()
emp_var_rate_entrybox=ttk.Entry(window,width=27,textvariable=emp_var_rate_var)
emp_var_rate_entrybox.grid(row=1,column=11)

#Column 13
duration = ttk.Label(window, text = "Duration :", font = ("Times New Roman", 10)).grid(column = 10,  row = 2, padx = 10, pady = 25)
duration_var=tk.StringVar()
duration_entrybox=ttk.Entry(window,width=27,textvariable=duration_var)
duration_entrybox.grid(row=2,column=11)

#Column 14
campaign = ttk.Label(window, text = "Campaign :", font = ("Times New Roman", 10)).grid(column = 10,  row = 3, padx = 10, pady = 25)
campaign_var=tk.StringVar()
campaign_choosen = ttk.Combobox(window, width = 27, textvariable = campaign_var)
campaign_choosen['values'] = (1,  3,  2,  8,  5,  4, 25, 11, 12, 18,  6, 17,  7, 20, 16, 14, 10,
        9, 19, 29, 13, 40, 15, 34, 22, 24, 41, 21, 23, 39, 28, 27, 31, 35,
    26, 30, 32, 43, 33, 42, 56, 37)
campaign_choosen.grid(row=3,column=11)
campaign_choosen.current(1)

#Column 15
pdays = ttk.Label(window, text = "Pdays :", font = ("Times New Roman", 10)).grid(column = 10,  row = 4, padx = 10, pady = 25)
pdays_var=tk.StringVar()
pdays_entrybox=ttk.Entry(window,width=27,textvariable=pdays_var)
pdays_entrybox.grid(row=4,column=11)

#Column 16
previous = ttk.Label(window, text = "Previous :", font = ("Times New Roman", 10)).grid(column = 10,  row = 5, padx = 10, pady = 25)
previous_var=tk.StringVar()
previous_choosen = ttk.Combobox(window, width = 27, textvariable = previous_var)
previous_choosen['values'] = (0, 2, 1, 3, 4, 5, 7, 6)
previous_choosen.grid(column = 11, row = 5)
previous_choosen.current(1)

#Column 17
cons_price_idx = ttk.Label(window, text = "Cons_price_idx :", font = ("Times New Roman", 10)).grid(column = 10,  row = 6, padx = 10, pady = 25)
cons_price_idx_var=tk.StringVar()
cons_price_idx_entrybox=ttk.Entry(window,width=27,textvariable=cons_price_idx_var)
cons_price_idx_entrybox.grid(row=6,column=11)

#Column 18
cons_conf_idx = ttk.Label(window, text = "Cons_conf_idx :", font = ("Times New Roman", 10)).grid(column = 10,  row = 7, padx = 10, pady = 25)
cons_conf_idx_var=tk.StringVar()
cons_conf_idx_entrybox=ttk.Entry(window,width=27,textvariable=cons_conf_idx_var)
cons_conf_idx_entrybox.grid(row=7,column=11)

#Column 19
euribor3m = ttk.Label(window, text = "Euriborem :", font = ("Times New Roman", 10)).grid(column = 10,  row = 8, padx = 10, pady = 25)
euribor3m_var=tk.StringVar()
euribor3m_entrybox=ttk.Entry(window,width=27,textvariable=euribor3m_var)
euribor3m_entrybox.grid(row=8,column=11)

#Column 20
nr_employed = ttk.Label(window, text = "nr_employed :", font = ("Times New Roman", 10)).grid(column = 10,  row = 9, padx = 10, pady = 25)
nr_employed_var=tk.StringVar()
nr_employed_entrybox=ttk.Entry(window,width=27,textvariable=nr_employed_var)
nr_employed_entrybox.grid(row=9,column=11)




import pandas as pd
DF = pd.DataFrame()

global DB
import pandas as pd
DF = pd.DataFrame(columns=['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
       'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
       'cons_conf_idx', 'euribor3m', 'nr_employed'])

def action():   
    AGE=age_var.get()
    DF.loc[0,'age']=AGE
    JOB=job_var.get()
    DF.loc[0,'job']=JOB
    MARITAL=marital_var.get()
    DF.loc[0,'marital']=MARITAL
    EDUCATION=education_var.get()
    DF.loc[0,'education']=EDUCATION
    DEFAULT=default_var.get()
    DF.loc[0,'default']=DEFAULT
    HOUSING=housing_var.get()
    DF.loc[0,'housing']=HOUSING
    LOAN=loan_var.get()
    DF.loc[0,'loan']=LOAN
    CONTACT=contact_var.get()
    DF.loc[0,'contact']=CONTACT
    
    MONTH=month_var.get()
    DF.loc[0,'month']=MONTH
    Day_Of_Week=day_of_week_var.get()
    DF.loc[0,'day_of_week']=Day_Of_Week
    DURATION=duration_var.get()
    DF.loc[0,'duration']=DURATION
    CAMPAIGN=campaign_var.get()
    DF.loc[0,'campaign']=CAMPAIGN
    PDAYS=pdays_var.get()
    DF.loc[0,'pdays']=PDAYS
    PREVIOUS=previous_var.get()
    DF.loc[0,'previous']=PREVIOUS
    POUT=poutcome_var.get()
    DF.loc[0,'poutcome']=POUT
    EMP_VAR=emp_var_rate_var.get()
    DF.loc[0,'emp_var_rate']=EMP_VAR
    
    CON_PRICE= cons_price_idx_var.get()
    DF.loc[0,'cons_price_idx']=CON_PRICE
    CONS=cons_conf_idx_var.get()
    DF.loc[0,'cons_conf_idx']=CONS
    EURI=euribor3m_var.get()
    DF.loc[0,'euribor3m']=EURI
    EMPLOY=nr_employed_var.get()
    DF.loc[0,'nr_employed']=EMPLOY
    
DB=DF

def filedreq():
    if age_var.get() == "":
        print("Age Field is Empty!!")
        user = "Age input is Empty!!"
        ttk.Label(window, text=user, font = ("Times New Roman", 10)).grid(row=11,column=1)


    elif duration_var.get() == "":
        print("duration Field is Empty!!")
        user = "duration Field is Empty!!"
        ttk.Label(window, text=user, font = ("Times New Roman", 10)).grid(row=12,column=1)
    
    elif pdays_var.get() == "":
        print("pdays Field is Empty!!")
        user = "pdays Field is Empty!!"
        ttk.Label(window, text=user, font = ("Times New Roman", 10)).grid(row=12,column=1)
    
    elif emp_var_rate_var.get() == "":
        print("emp_var_rate Field is Empty!!")
        user = "emp_var_rate Field is Empty!!"
        ttk.Label(window, text=user, font = ("Times New Roman", 10)).grid(row=12,column=1)
    elif cons_price_idx_var.get() == "":
        print("cons_price_idx Field is Empty!!")
        user = "cons_price_idx Field is Empty!!"
        ttk.Label(window, text=user, font = ("Times New Roman", 10)).grid(row=12,column=1)
    elif cons_conf_idx_var.get() == "":
        print("cons_conf_idx Field is Empty!!")
        user = "cons_conf_idx Field is Empty!!"
        ttk.Label(window, text=user, font = ("Times New Roman", 10)).grid(row=12,column=1)
    elif euribor3m_var.get() == "":
        print("euriborem Field is Empty!!")
        user = "euriborem Field is Empty!!"
        ttk.Label(window, text=user, font = ("Times New Roman", 10)).grid(row=12,column=1)
    elif nr_employed_var.get() == "":
        print("nr_employed Field is Empty!!")
        user = "nr_employed Field is Empty!!"
        ttk.Label(window, text=user, font = ("Times New Roman", 10)).grid(row=12,column=1)
    else:
        pass

def Output():
    action()
    filedreq()
    DB["age"] = pd.to_numeric(DB["age"])
    DB["duration"] = pd.to_numeric(DB["duration"])
    DB["campaign"] = pd.to_numeric(DB["campaign"])
    DB["pdays"] = pd.to_numeric(DB["pdays"])
    DB["previous"] = pd.to_numeric(DB["previous"])
    DB["emp_var_rate"] = pd.to_numeric(DB["emp_var_rate"])
    DB["cons_price_idx"] = pd.to_numeric(DB["cons_price_idx"])
    DB["cons_conf_idx"] = pd.to_numeric(DB["cons_conf_idx"])
    DB["euribor3m"] = pd.to_numeric(DB["euribor3m"])
    DB["nr_employed"] = pd.to_numeric(DB["nr_employed"])
    DB['job'] = DB['job'].map({'blue-collar':0, 'technician':1, 'management':2, 'services':3,'retired':4, 'admin.':5, 'housemaid':6, 'unemployed':7, 'entrepreneur':8, 'self-employed':9, 'unknown':10, 'student':11}).astype(int) 
    DB['marital'] = DB['marital'].map({'married':0, 'single':1, 'divorced':2, 'unknown':3}).astype(int)
    DB['education'] = DB['education'].map({'basic.4y':0, 'unknown':1, 'university.degree':2, 'high.school':3, 'basic.9y':4,'professional.course':5, 'basic.6y':6, 'illiterate':7}).astype(int)
    DB['default'] = DB['default'].map({'unknown':0, 'no':1, 'yes':2}).astype(int)
    DB['housing'] = DB['housing'].map({'unknown':0, 'no':1, 'yes':2}).astype(int)
    DB['loan'] = DB['loan'].map({'unknown':0, 'no':1, 'yes':2}).astype(int)
    DB['contact'] = DB['contact'].map({'cellular':0, 'telephone':1}).astype(int)
    DB['month'] = DB['month'].map({'aug':0, 'nov':1, 'jun':2, 'apr':3, 'jul':4, 'may':5, 'oct':6, 'mar':7, 'sep':8,
           'dec':9,'feb':10,'jan':11}).astype(int)
    DB['day_of_week'] = DB['day_of_week'].map({'thu':3, 'fri':4,'sat':5, 'sun':6, 'tue':1, 'mon':0, 'wed':2}).astype(int)
    DB['poutcome'] = DB['poutcome'].map({'nonexistent':0, 'success':1, 'failure':2}).astype(int)
   
    db = scaler.transform(DB)


    output=loaded_svc_rbl.predict(db)
    #print(output)
    if output == 1:
        MsgBox = messagebox.showinfo("Marketing_campaign results", 'Campaign got positive response')
        
    else:
        MsgBox = messagebox.showinfo('Marketing_campaign results', 'Campaign got no response')
        

def reset():
    nr_employed_var.set("")
    age_var.set("")
    duration_var.set("")
    pdays_var.set("")
    emp_var_rate_var.set("")
    cons_conf_idx_var.set("")
    euribor3m_var.set("")
    
 

    
Predict_button=ttk.Button(window,text="Predict",command=Output,width=25)
Predict_button.grid(row=10,column=15)

reset_button=ttk.Button(window,text="Reset",command=reset,width=25)
reset_button.grid(row=10,column=11)


window.mainloop()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
import pandas as pd

df = pd.read_csv("banking.csv")

df['job'] = df['job'].map({'blue-collar':0, 'technician':1, 'management':2, 'services':3,'retired':4, 'admin.':5, 'housemaid':6, 'unemployed':7, 'entrepreneur':8, 'self-employed':9, 'unknown':10, 'student':11}).astype(int) 
df['marital'] = df['marital'].map({'married':0, 'single':1, 'divorced':2, 'unknown':3}).astype(int)
df['education'] = df['education'].map({'basic.4y':0, 'unknown':1, 'university.degree':2, 'high.school':3, 'basic.9y':4,'professional.course':5, 'basic.6y':6, 'illiterate':7}).astype(int)
df['default'] = df['default'].map({'unknown':0, 'no':1, 'yes':2}).astype(int)
df['housing'] = df['housing'].map({'unknown':0, 'no':1, 'yes':2}).astype(int)
df['loan'] = df['loan'].map({'unknown':0, 'no':1, 'yes':2}).astype(int)
df['contact'] = df['contact'].map({'cellular':0, 'telephone':1}).astype(int)
df['month'] = df['month'].map({'aug':0, 'nov':1, 'jun':2, 'apr':3, 'jul':4, 'may':5, 'oct':6, 'mar':7, 'sep':8,
       'dec':9,'feb':10,'apr':11}).astype(int)
df['day_of_week'] = df['day_of_week'].map({'thu':3, 'fri':4,'sat':5, 'sun':6, 'tue':1, 'mon':0, 'wed':2}).astype(int)
df['poutcome'] = df['poutcome'].map({'nonexistent':0, 'success':1, 'failure':2}).astype(int)


y = df['y']
X = df.drop('y', axis =1)


x_train_orginal, x_test_orginal, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.2)
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train_orginal)
x_test = scaler.fit_transform(x_test_orginal)

# %%
import streamlit as st
import pickle
import pandas as pd
def achieved(url): 
    st.markdown(f'<p style="color:#32CD32;font-size:35px;"><strong>{url}</strong></p>', unsafe_allow_html=True)
    
def non_achieved(url): 
    st.markdown(f'<p style="color:#ff0000;font-size:35px;"><strong>{url}</strong></p>', unsafe_allow_html=True)
def svc_predict():
    col1, col2 = st.columns([1,1])

    with col1:
         st.image("woxsen_logo.png")


    with col2:
        st.image("appstek_logo.jpg")

    st.header("Market Campaign Prediction")
    output_list = []
 
    
    col1, col2 = st.columns([1,1])
    with col1:
        age=st.text_input('age',12)
        output_list.append(int(age))
        

    with col2:
        job_list = ['blue-collar', 'technician', 'management', 'services','retired', 'admin.', 'housemaid', 'unemployed', 'entrepreneur', 'self-employed', 'unknown', 'student']
        job_type = st.selectbox("Select the job type:",job_list)
        job_dict = {'blue-collar':0, 'technician':1, 'management':2, 'services':3,'retired':4, 'admin.':5, 'housemaid':6, 'unemployed':7, 'entrepreneur':8, 'self-employed':9, 'unknown':10, 'student':11}
        output_list.append( job_dict[job_type])
        
      


    col1 , col2 = st.columns([1,1])
    with col1:
        marital_list=['married', 'single', 'divorced', 'unknown']
        marital=st.selectbox("Select the marital :",marital_list)
        marital_dict = {'married':0, 'single':1, 'divorced':2, 'unknown':3}
        output_list.append(marital_dict[marital])
        
      
       

    with col2:
        education_list=['basic.4y', 'unknown', 'university.degree', 'high.school', 'basic.9y','professional.course', 'basic.6y', 'illiterate']
        education=st.selectbox("Select the education :",education_list)
        education_dict = {'basic.4y':0, 'unknown':1, 'university.degree':2, 'high.school':3, 'basic.9y':4,'professional.course':5, 'basic.6y':6, 'illiterate':7}
        output_list.append(education_dict[education])
        
        



    col1 , col2 = st.columns([1,1])
    with col1:
        default_list=['unknown', 'no', 'yes']
        default=st.selectbox("Select the default :",default_list)
        default_dict={'unknown':0, 'no':1, 'yes':2}
        output_list.append( default_dict[ default])
        

    with col2:
        housing_list=['unknown', 'no', 'yes']
        housing=st.selectbox("Select the housing :",housing_list)
        housing_dict={'unknown':0, 'no':1, 'yes':2}
        output_list.append( housing_dict[ housing])
        


        
    col1 , col2 = st.columns([1,1])
    with col1:
        loan_satus_list=['unknown', 'no', 'yes']
        loan_satus=st.selectbox("Select the loan_satus :",loan_satus_list)
        loan_dict={'unknown':0, 'no':1, 'yes':2}
        output_list.append( loan_dict[ loan_satus])
        




    
    with col2:
        contact_list=['cellular', 'telephone']
        contact =st.selectbox("Select the contact :",contact_list)
        contact_dict={'cellular':0, 'telephone':1}
        output_list.append(  contact_dict[ contact])

    col1 , col2 = st.columns([1,1])   
    with col1:
        month_list=['aug', 'nov', 'jun', 'apr', 'jul', 'may', 'oct', 'mar', 'sep', 'dec','feb','jan']
        month=st.selectbox("Select the month :",month_list)
        month_dict={'aug':0, 'nov':1, 'jun':2, 'apr':3, 'jul':4, 'may':5, 'oct':6, 'mar':7, 'sep':8,
       'dec':9,'feb':10,'apr':11}
        output_list.append( month_dict[ month])
        
        




    
    with col2:
        day_list=['thu', 'fri','sat', 'sun', 'tue', 'mon', 'wed']
        day =st.selectbox("Select the  day :", day_list)
        day_dict={'thu':3, 'fri':4,'sat':5, 'sun':6, 'tue':1, 'mon':0, 'wed':2}
        output_list.append( day_dict[ day])


    col1 , col2 = st.columns([1,1])
    with col1:
        Campaign=st.text_input('Campaign:',0)
        output_list.append(int(Campaign))
    with col2:
        Pdays=st.text_input('Pdays:',0)
        output_list.append(int(Pdays))


    col1 , col2 = st.columns([1,1])   
    with col1:
        Previous=st.text_input('Previous',0)
        output_list.append(int(Previous))
                  
    with col2:
        poutcome_list=['nonexistent', 'success', 'failure']
        poutcome=st.selectbox("Select the  poutcome:", poutcome_list)
        poutcome_dict={'nonexistent':0, 'success':1, 'failure':2}
        output_list.append( poutcome_dict[ poutcome])



    col1 , col2 = st.columns([1,1])
    with col1:
        emp_var_rate=st.text_input('emp_var_rate:',2)
        output_list.append(int(emp_var_rate))
        

    with col2:
        Duration=st.text_input('Duration:',2)
        output_list.append(int(Duration))
        
    col1 , col2 = st.columns([1,1])  
    with col1:
        Cons_price_idx=st.text_input('Cons_price_idx:',2)
        output_list.append(int(Cons_price_idx))
        
    with col2:
        Cons_conf_idx=st.text_input('Cons_conf_idx:',2)
        output_list.append(int( Cons_conf_idx))
        
    col1 , col2 = st.columns([1,1])    
    with col1:
        Euriborem =st.text_input('Euriborem :',2)
        output_list.append(int( Euriborem))
        

    with col2:
        nr_employed =st.text_input('nr_employed :',2)
        output_list.append(int( nr_employed))
        
        
    

    if st.button("Predict"):

        df = pd.DataFrame(columns=['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
       'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
       'cons_conf_idx', 'euribor3m', 'nr_employed'])
        df.loc[0,:] = output_list
        
        #x_test = scaler.fit_transform(df)
        
        with open('Marketing_campaign.pkl', 'rb') as f:
            loaded_svc_linear = pickle.load(f)

        output=loaded_svc_linear.predict(df)

        
        if output[0] == 1:
            with col3:
                 achieved("The Markerting campaign will be successful")
            
        else:
            non_achieved("The Markerting campaign won't successful")


if __name__ == "__main__":
    svc_predict()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a7a0aba66739> in <module>
#     191
#     192 if __name__ == "__main__":
# --> 193     svc_predict()
#
# <ipython-input-2-a7a0aba66739> in svc_predict()
#      11
#      12     with col1:
# ---> 13          st.image("woxsen_logo.png")
#      14
#      15
#
# ~\anaconda3\lib\site-packages\streamlit\elements\image.py in image(self, image, caption, width, use_column_width, clamp, channels, output_format)
#     118
#     119         image_list_proto = ImageListProto()
# --> 120         marshall_images(
#     121             self.dg._get_delta_path_str(),
#     122             image,
#
# ~\anaconda3\lib\site-packages\streamlit\elements\image.py in marshall_images(coordinates, image, caption, width, proto_imgs, clamp, channels, output_format)
#     368                 is_svg = True
#     369         if not is_svg:
# ...
